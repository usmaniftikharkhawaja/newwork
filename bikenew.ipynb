# %%
def calculate_security_deposit(price, sec_amount):
    sec_dep = price * (sec_amount / 100)
    print(f"Security Deposit is: {sec_dep} @ {sec_amount}% of retail price")
    return sec_dep

price = int(input("Enter the price of vehicle: "))
print("The bike price is:", price)
sec_amount = int(input("Enter the security %: "))
pro_fee = 1800

if sec_amount not in range(15, 51, 5):
    sec_amount = 50

sec_dep = calculate_security_deposit(price, sec_amount)

price_new = price + price * 0.117 + pro_fee
remaining = price_new - sec_dep
total_left = pro_fee + remaining
print("Total left amount is:", total_left)

months = int(input("Enter number of months for installments: "))
total_upfront = sec_dep + pro_fee

if months == 12:
    price_monthly = remaining / 12
    print("Installment per month will be: ", price_monthly)

print("Installment total amount will be: ", price_new)

price_on_installments = (price_new + total_upfront - pro_fee)
print('Price on installments is: ', price_on_installments)
# Out:
# The bike price is: 55000
# Security Deposit is: 27500.0 @ 50% of retail price
# Total left amount is: 37535.0
# Installment per month will be:  2977.9166666666665
# Installment total amount will be:  63235.0
# Price on installments is:  90735.0

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError

try:
    html = urlopen("https://facebook.com")
except HTTPError as e:
    print("HTTP error")
except URLError as e:
    print("Server not found!")
else:
    print(html.read())
    
try:
    html = urlopen("http://www.example.com/")
except HTTPError as e:
    print("HTTP error")
except URLError as e:
    print("Server not found!")
else:
    print("HTML Details")    
    print(html.read())
# Out:
# b'<!DOCTYPE html>\n<html lang="ur" id="facebook" class="no_js">\n<head><meta charset="utf-8" /><meta name="referrer" content="default" id="meta_referrer" /><script nonce="VuLdLVJK">function envFlush(a){function b(b){for(var c in a)b[c]=a[c]}window.requireLazy?window.requireLazy(["Env"],b):(window.Env=window.Env||{},b(window.Env))}envFlush({"useTrustedTypes":false,"isTrustedTypesReportOnly":false,"ajaxpipe_token":"AXhwsjdijVw1hxHXeFc","stack_trace_limit":30,"timesliceBufferSize":5000,"show_invariant_decoder":false,"compat_iframe_token":"AQ7U1qO3hGYGhzaJJPA","isCQuick":false});</script><script nonce="VuLdLVJK">(function(a){function b(b){if(!window.openDatabase)return;b.I_AM_INCOGNITO_AND_I_REALLY_NEED_WEBSQL=function(a,b,c,d){return window.openDatabase(a,b,c,d)};window.openDatabase=function(){throw new Error()}}b(a)})(this);</script><style nonce="VuLdLVJK"></style><script nonce="VuLdLVJK">__DEV__=0;</script><noscript><meta http-equiv="refresh" content="0; URL=/?_fb_noscript=1" /></nosc
# ...

# %% [markdown]
# A binary gap within a positive integer N is any maximal sequence of consecutive zeros that is surrounded by ones at both ends in the binary representation of N.
#
# For example, number 9 has binary representation 1001 and contains a binary gap of length 2. The number 529 has binary representation 1000010001 and contains two binary gaps: one of length 4 and one of length 3. The number 20 has binary representation 10100 and contains one binary gap of length 1. The number 15 has binary representation 1111 and has no binary gaps. The number 32 has binary representation 100000 and has no binary gaps.
#
# Write a function:
#
# def solution(N)
#
# that, given a positive integer N, returns the length of its longest binary gap. The function should return 0 if N doesn't contain a binary gap.
#
# For example, given N = 1041 the function should return 5, because N has binary representation 10000010001 and so its longest binary gap is of length 5. Given N = 32 the function should return 0, because N has binary representation '100000' and thus no binary gaps.
#
# Write an efficient algorithm for the following assumptions:
#
# N is an integer within the range [1..2,147,483,647].

# %%
 

def solution(N):
    binary_representation = bin(N)[2:]  # Convert the integer to its binary representation and remove the '0b' prefix
    max_gap = 0
    current_gap = 0

    for bit in binary_representation:
        if bit == '0':
            current_gap += 1
        else:
            max_gap = max(max_gap, current_gap)
            current_gap = 0

    return max_gap

# %%
def solution(N):
    # Convert N to binary representation
    binary = bin(N)[2:]

    # Variables to track the maximum gap length and current gap length
    max_gap = 0
    current_gap = 0

    # Flag to indicate if counting gap should start
    count_gap = False

    # Iterate over each digit in the binary representation
    for digit in binary:
        if digit == '1':
            # Check if a gap is ending and update the maximum gap length
            if count_gap:
                max_gap = max(max_gap, current_gap)
                current_gap = 0
            # Set the flag to start counting a new gap
            count_gap = True
        elif count_gap:
            # If a gap is being counted, increment the current gap length
            current_gap += 1

    return max_gap

# Example usage
print(solution(1041))  # Output: 5
print(solution(32))    # Output: 0
# Out:
# 5
# 0

# %%
def solution(A, K):
    if len(A) == 0 or len(A) == 1:
        return A
    K = K % len(A)
    return A[-K:] + A[:-K]

A = [3, 8, 9, 7, 6]
K = 3
print(solution(A, K)) # Output: [9, 7, 6, 3, 8]

A = [0 , 0]
K = 1
print(solution(A, K)) # Output: [0, 0, 0]

A = [1, 2, 3, 4]
K = 1
print(solution(A, K)) # Output: [1, 2, 3, 4]
# Out:
# [9, 7, 6, 3, 8]
# [0, 0]
# [4, 1, 2, 3]

# %%
#while loop
